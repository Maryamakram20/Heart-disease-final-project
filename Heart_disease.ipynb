# %% [markdown]
# <a href="https://colab.research.google.com/github/Maryamakram20/Heart-disease-final-project/blob/Project-submition/Heart_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data = data.rename(columns={"cp": "chest_pain", "trestbps": "blood_pressure", "fbs": "blood_sugar","target": "Heart_disease", "sex": "gender","ca": "vessels", "chol": "cholesterol"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1025 non-null   int64
#  1   gender          1025 non-null   int64
#  2   chest_pain      1025 non-null   int64
#  3   blood_pressure  1025 non-null   int64
#  4   cholesterol     1025 non-null   int64
#  5   blood_sugar     1025 non-null   int64
#  6   restecg         1025 non-null   int64
#  7   thalach         1025 non-null   int64
#  8   exang           1025 non-null   int64
#  9   oldpeak         1025 non-null   float64
#  10  slope           1025 non-null   int64
#  11  vessels         1025 non-null   int64
#  12  thal            1025 non-null   int64
#  13  Heart_disease   1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.describe()
# Out:
#                age       gender   chest_pain  blood_pressure  cholesterol  \
# count  1025.000000  1025.000000  1025.000000     1025.000000   1025.00000
# mean     54.434146     0.695610     0.942439      131.611707    246.00000
# std       9.072290     0.460373     1.029641       17.516718     51.59251
# min      29.000000     0.000000     0.000000       94.000000    126.00000
# 25%      48.000000     0.000000     0.000000      120.000000    211.00000
# 50%      56.000000     1.000000     1.000000      130.000000    240.00000
# 75%      61.000000     1.000000     2.000000      140.000000    275.00000
# max      77.000000     1.000000     3.000000      200.000000    564.00000
#
#        blood_sugar      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data['Heart_disease'] = ["No" if x == 0 else "yes" for x in data['Heart_disease']]

# %%
#data['gender'] = ['Female' if x == 0 else 'Male' for x in data['gender']]

# %%
data.head()
# Out:
#    age  gender  chest_pain  blood_pressure  cholesterol  blood_sugar  restecg  \
# 0   52       1           0             125          212            0        1
# 1   53       1           0             140          203            1        0
# 2   70       1           0             145          174            0        1
# 3   61       1           0             148          203            0        1
# 4   62       0           0             138          294            1        1
#
#    thalach  exang  oldpeak  slope  vessels  thal Heart_disease
# 0      168      0      1.0      2        2     3            No
# 1      155      1      3.1      0        0     3            No
# 2      125      1      2.6      0        0     3            No
# 3      161      0      0.0      2        1     3            No
# 4      106      0      1.9      1        3     2            No

# %%
data["Heart_disease"].unique()
# Out:
# array(['No', 'yes'], dtype=object)

# %%
data['Heart_disease'].value_counts()
# Out:
# yes    526
# No     499
# Name: Heart_disease, dtype: int64

# %%
sns.set(font_scale=2)
data.hist(figsize=(30,30))
plt.show()

# %%
data.groupby(['gender', 'Heart_disease'])['gender'].count()
# Out:
# gender  Heart_disease
# 0       No                86
#         yes              226
# 1       No               413
#         yes              300
# Name: gender, dtype: int64

# %%
sns.countplot(data=data, x='gender', hue='Heart_disease')

# %%
data["chest_pain"].unique()
# Out:
# array([0, 1, 2, 3])

# %%
sns.countplot(data=data, x='chest_pain', hue='Heart_disease')

# %%
data["slope"].unique()
# Out:
# array([2, 0, 1])

# %%
sns.countplot(data=data, x='slope', hue='Heart_disease')

# %%
sns.countplot(data=data, x='thal', hue='Heart_disease')

# %%
sns.countplot(data=data, x='vessels', hue='Heart_disease')

# %%
#sns.distplot(data['age'])

# %%
#sns.distplot(data['blood_pressure'])

# %%
sns.pairplot(data , vars = ['age', 'cholesterol', 'thal', 'oldpeak'], hue='Heart_disease')

# %%
data.columns
# Out:
# Index(['age', 'gender', 'chest_pain', 'blood_pressure', 'cholesterol',
#        'blood_sugar', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope',
#        'vessels', 'thal', 'Heart_disease'],
#       dtype='object')

# %%
categorical_values = list(data.columns)

# %%
categorical_values.remove('Heart_disease')

# %%
print(list(enumerate(categorical_values, 1)))
# Out:
# [(1, 'age'), (2, 'gender'), (3, 'chest_pain'), (4, 'blood_pressure'), (5, 'cholesterol'), (6, 'blood_sugar'), (7, 'restecg'), (8, 'thalach'), (9, 'exang'), (10, 'oldpeak'), (11, 'slope'), (12, 'vessels'), (13, 'thal')]

# %%
plt.figure(figsize=(60,60))

for i, col in enumerate(categorical_values, 1):
    plt.subplot(4,4,i)
    plt.scatter(x=f"{col}",y='Heart_disease', data=data, )
    plt.ylabel(" Heart Disease")
    plt.xlabel(f"{col}")

# %%
data.corr()
# Out:
#                      age    gender  chest_pain  blood_pressure  cholesterol  \
# age             1.000000 -0.103240   -0.071966        0.271121     0.219823
# gender         -0.103240  1.000000   -0.041119       -0.078974    -0.198258
# chest_pain     -0.071966 -0.041119    1.000000        0.038177    -0.081641
# blood_pressure  0.271121 -0.078974    0.038177        1.000000     0.127977
# cholesterol     0.219823 -0.198258   -0.081641        0.127977     1.000000
# blood_sugar     0.121243  0.027200    0.079294        0.181767     0.026917
# restecg        -0.132696 -0.055117    0.043581       -0.123794    -0.147410
# thalach        -0.390227 -0.049365    0.306839       -0.039264    -0.021772
# exang           0.088163  0.139157   -0.401513        0.061197     0.067382
# oldpeak         0.208137  0.084687   -0.174733        0.187434     0.064880
# slope          -0.169105 -0.026666    0.131633       -0.120445    -0.014248
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
arr = data.values
X = arr[:,0:-1]
Y = arr[:,-1]
testing_size = 0.2
print(Y)
# Out:
# ['No' 'No' 'No' ... 'No' 'yes' 'No']

# %%
data['Heart_disease']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 1020    yes
# 1021     No
# 1022     No
# 1023    yes
# 1024     No
# Name: Heart_disease, Length: 1025, dtype: object

# %%
X = data.drop('Heart_disease', axis=1)
Y = data['Heart_disease']
print(Y)
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 1020    yes
# 1021     No
# 1022     No
# 1023    yes
# 1024     No
# Name: Heart_disease, Length: 1025, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=testing_size)

print(Y_test)
# Out:
# 738      No
# 464     yes
# 326      No
# 85      yes
# 1005     No
#        ...
# 944      No
# 621      No
# 261     yes
# 534     yes
# 840      No
# Name: Heart_disease, Length: 205, dtype: object

# %%
models = []
models.append(('DT',DecisionTreeClassifier()))
models.append(('RT',RandomForestClassifier()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('LR', LogisticRegression()))
models.append(('GNB', GaussianNB()))
print(models)
# Out:
# [('DT', DecisionTreeClassifier()), ('RT', RandomForestClassifier()), ('KNN', KNeighborsClassifier()), ('LR', LogisticRegression()), ('GNB', GaussianNB())]

# %%
names = []
results = []

for name, model in models:
    obj = model
    names.append(name)
    obj.fit(X_train, Y_train)
    Y_pred = obj.predict(X_test)
    results.append(accuracy_score(Y_test, Y_pred)*100)
    print(results)
# Out:
# [100.0]
# [100.0, 100.0]
# [100.0, 100.0, 72.6829268292683]
# [100.0, 100.0, 72.6829268292683, 85.36585365853658]
# [100.0, 100.0, 72.6829268292683, 85.36585365853658, 81.46341463414633]

# %%
plt.scatter(names, results)
plt.show()

# %%
from sklearn.metrics import confusion_matrix as cm

# %%
conf = cm(Y_test, Y_pred)
sns.heatmap(conf)
print(conf)
# Out:
# [[74 30]
#  [ 8 93]]
